# %% [markdown]
# # My implementation of Used Car Price Prediction model
# ## Sakher Alqaaidi
# Kaggle real dataset
# Dataset contains both numerical and text values, thus, NLP preprocessing methods are followed
# Scikit Learn

# %%
import pandas as pd
from sklearn import preprocessing

# %%
df = pd.read_csv('data/used_car_dataset.csv')

# %%
# observe 10 random samples
df.sample(10)
# Out:
#                                      car_name car_price_in_rupees kms_driven  \
# 371     Hyundai Santro Sportz CNG [2018-2020]         ₹ 5.23 Lakh  40,067 km
# 327                    BMW X1 sDrive20d xLine        ₹ 21.45 Lakh  46,595 km
# 431         Hyundai Santro Sportz [2018-2020]         ₹ 5.54 Lakh  11,844 km
# 877               Maruti Suzuki Swift VXi AMT         ₹ 7.04 Lakh  28,151 km
# 389   Hyundai Venue SX 1.0 Petrol [2019-2020]        ₹ 10.66 Lakh  24,783 km
# 1902                           Toyota Etios G         ₹ 2.75 Lakh  70,000 km
# 885         Maruti Suzuki Wagon R 1.0 VXI AMT            ₹ 4 Lakh  25,299 km
# 1954      Hyundai Elite i20 Asta 1.4 (O) CRDi         ₹ 5.51 Lakh      91 km
# 1084        Hyundai Creta SX Plus 1.6 AT CRDI        ₹ 11.71 Lakh  44,157 km
# 643          Renault Duster 110 PS RxZ Diesel          ₹ 5.7 Lakh  56,816 km
#
#      fuel_type       city  year_of_manufacture
# 371        CNG       Pune                 2018
# 327     Diesel      Delhi                 2018
# 431     Petrol       Pune                 2019
# 877     Petrol      Delhi                 2019
# 389     Petrol  Bangalore                 2020
# 1902    Petrol      Noida                 2011
# 885     Petrol     Mumbai                 2015
# 1954    Diesel  Ahmedabad                 2015
# 1084    Diesel     Mumbai                 2017
# 643     Diesel      Thane                 2014

# %%
# encode categorical features, year
le = preprocessing.LabelEncoder()
year_encoded = le.fit_transform(df['year_of_manufacture'])
df['year_encoded'] = year_encoded
print( df['year_encoded'].describe() )
print( le.inverse_transform([13]) )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 # encode categorical features, year
#       2 le = preprocessing.OrdinalEncoder()
# ----> 3 year_encoded = le.fit_transform(df['year_of_manufacture'])
#       4 df['year_encoded'] = year_encoded
#       5 print( df['year_encoded'].describe() )
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=139'>140</a> @wraps(f)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=140'>141</a> def wrapped(self, X, *args, **kwargs):
# --> <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=141'>142</a>     data_to_wrap = f(self, X, *args, **kwargs)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=142'>143</a>     if isinstance(data_to_wrap, tuple):
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=143'>144</a>         # only wrap the first output for cross decomposition
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=144'>145</a>         return (
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=145'>146</a>             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=146'>147</a>             *data_to_wrap[1:],
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=147'>148</a>         )
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=139'>140</a> @wraps(f)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=140'>141</a> def wrapped(self, X, *args, **kwargs):
# --> <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=141'>142</a>     data_to_wrap = f(self, X, *args, **kwargs)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=142'>143</a>     if isinstance(data_to_wrap, tuple):
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=143'>144</a>         # only wrap the first output for cross decomposition
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=144'>145</a>         return (
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=145'>146</a>             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=146'>147</a>             *data_to_wrap[1:],
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=147'>148</a>         )
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=139'>140</a> @wraps(f)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=140'>141</a> def wrapped(self, X, *args, **kwargs):
# --> <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=141'>142</a>     data_to_wrap = f(self, X, *args, **kwargs)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=142'>143</a>     if isinstance(data_to_wrap, tuple):
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=143'>144</a>         # only wrap the first output for cross decomposition
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=144'>145</a>         return (
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=145'>146</a>             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=146'>147</a>             *data_to_wrap[1:],
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py?line=147'>148</a>         )
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/base.py:848, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/base.py?line=843'>844</a> # non-optimized default implementation; override when a better
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/base.py?line=844'>845</a> # method is possible for a given clustering algorithm
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/base.py?line=845'>846</a> if y is None:
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/base.py?line=846'>847</a>     # fit method of arity 1 (unsupervised transformation)
# --> <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/base.py?line=847'>848</a>     return self.fit(X, **fit_params).transform(X)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/base.py?line=848'>849</a> else:
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/base.py?line=849'>850</a>     # fit method of arity 2 (supervised transformation)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/base.py?line=850'>851</a>     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:1238, in OrdinalEncoder.fit(self, X, y)
#    <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=1230'>1231</a>     raise TypeError(
#    <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=1231'>1232</a>         "unknown_value should only be set when "
#    <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=1232'>1233</a>         "handle_unknown is 'use_encoded_value', "
#    <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=1233'>1234</a>         f"got {self.unknown_value}."
#    <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=1234'>1235</a>     )
#    <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=1236'>1237</a> # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=1237'>1238</a> self._fit(X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan")
#    <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=1239'>1240</a> if self.handle_unknown == "use_encoded_value":
#    <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=1240'>1241</a>     for feature_cats in self.categories_:
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:74, in _BaseEncoder._fit(self, X, handle_unknown, force_all_finite, return_counts)
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=71'>72</a> self._check_n_features(X, reset=True)
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=72'>73</a> self._check_feature_names(X, reset=True)
# ---> <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=73'>74</a> X_list, n_samples, n_features = self._check_X(
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=74'>75</a>     X, force_all_finite=force_all_finite
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=75'>76</a> )
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=76'>77</a> self.n_features_in_ = n_features
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=78'>79</a> if self.categories != "auto":
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:46, in _BaseEncoder._check_X(self, X, force_all_finite)
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=32'>33</a> """
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=33'>34</a> Perform custom check_array:
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=34'>35</a> - convert list of strings to object dtype
#    (...)
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=41'>42</a>
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=42'>43</a> """
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=43'>44</a> if not (hasattr(X, "iloc") and getattr(X, "ndim", 0) == 2):
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=44'>45</a>     # if not a dataframe, do normal check_array validation
# ---> <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=45'>46</a>     X_temp = check_array(X, dtype=None, force_all_finite=force_all_finite)
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=46'>47</a>     if not hasattr(X, "dtype") and np.issubdtype(X_temp.dtype, np.str_):
#      <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py?line=47'>48</a>         X = check_array(X, dtype=object, force_all_finite=force_all_finite)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py:900, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=897'>898</a>     # If input is 1D raise error
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=898'>899</a>     if array.ndim == 1:
# --> <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=899'>900</a>         raise ValueError(
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=900'>901</a>             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=901'>902</a>             "Reshape your data either using array.reshape(-1, 1) if "
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=902'>903</a>             "your data has a single feature or array.reshape(1, -1) "
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=903'>904</a>             "if it contains a single sample.".format(array)
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=904'>905</a>         )
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=906'>907</a> if dtype_numeric and array.dtype.kind in "USV":
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=907'>908</a>     raise ValueError(
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=908'>909</a>         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=909'>910</a>         "Convert your data to numeric values explicitly instead."
#     <a href='file:///home/sak/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py?line=910'>911</a>     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[2016 2019 2021 ... 2018 2017 2017].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
# encode categorical features, city
city_encoded = le.fit_transform(df['city'])
df['city_encoded'] = city_encoded
print( df['city_encoded'].describe() )
print( le.inverse_transform([7]) )
# Out:
# count    2105.000000
# mean        7.145368
# std         4.667129
# min         0.000000
# 25%         3.000000
# 50%         8.000000
# 75%        11.000000
# max        15.000000
# Name: city_encoded, dtype: float64
# ['Hyderabad']

# %%
# encode categorical features, fuel_type
fuel_encoded = le.fit_transform(df['fuel_type'])
df['fuel_encoded'] = fuel_encoded
print( df['fuel_encoded'].describe() )
print( le.inverse_transform([4]) )
# Out:
# count    2105.000000
# mean        4.233729
# std         2.438892
# min         0.000000
# 25%         1.000000
# 50%         6.000000
# 75%         6.000000
# max         7.000000
# Name: fuel_encoded, dtype: float64
# ['Hybrid']

# %%
# transform kms_driven to numerical
fix_kms = lambda x: int( x[:-3].replace(',', '') )
df['kms_fixed'] = list( map(fix_kms, df['kms_driven']) )
print( df['kms_fixed'].describe() )
# Out:
# count    2.105000e+03
# mean     4.830131e+04
# std      8.372047e+04
# min      6.400000e+01
# 25%      2.499300e+04
# 50%      4.282500e+04
# 75%      6.300000e+04
# max      3.600000e+06
# Name: kms_fixed, dtype: float64

# %%
df
# Out:
#                                                car_name car_price_in_rupees  \
# 0     Hyundai Grand i10 Magna 1.2 Kappa VTVT [2017-2...         ₹ 4.45 Lakh
# 1                            Maruti Suzuki Alto 800 Lxi         ₹ 2.93 Lakh
# 2                               Tata Safari XZ Plus New        ₹ 22.49 Lakh
# 3                               Maruti Suzuki Ciaz ZXI+         ₹ 6.95 Lakh
# 4        Jeep Compass Sport Plus 1.4 Petrol [2019-2020]           ₹ 12 Lakh
# ...                                                 ...                 ...
# 2100                         Ford Figo Titanium1.5 TDCi          ₹ 3.6 Lakh
# 2101                    MINI Cooper Countryman Cooper D           ₹ 22 Lakh
# 2102                          Hyundai Verna 1.6 VTVT SX         ₹ 8.38 Lakh
# 2103                         Maruti Suzuki Ciaz VXi+ AT         ₹ 6.75 Lakh
# 2104                          Hyundai Verna 1.6 VTVT SX         ₹ 8.76 Lakh
#
#      kms_driven fuel_type       city  year_of_manufacture  year_encoded  \
# 0     22,402 km    Petrol     Mumbai                 2016            12
# 1     10,344 km    Petrol    Kolkata                 2019            15
# 2     12,999 km    Diesel  Bangalore                 2021            17
# 3     45,000 km    Petrol      Thane                 2016            12
# 4     11,193 km    Petrol    Kolkata                 2019            15
# ...         ...       ...        ...                  ...           ...
# 2100  42,158 km    Diesel    Kolkata                 2015            11
# 2101  68,862 km    Diesel  Hyderabad                 2013             9
# 2102  37,622 km    Petrol    Chennai                 2018            14
# 2103  64,726 km    Petrol     Mumbai                 2017            13
# 2104  29,150 km    Petrol       Pune                 2017            13
#
#       city_encoded  fuel_encoded  kms_fixed
# 0                9             6      22402
# 1                8             6      10344
# 2                2             1      12999
# 3               14             6      45000
# 4                8             6      11193
# ...            ...           ...        ...
# 2100             8             1      42158
# 2101             7             1      68862
# 2102             3             6      37622
# 2103             9             6      64726
# 2104            13             6      29150
#
# [2105 rows x 10 columns]
